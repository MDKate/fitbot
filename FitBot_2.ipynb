# %% [markdown]
# <a href="https://colab.research.google.com/github/MDKate/fitbot/blob/master/FitBot_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# #Бот

# %%
# !pip freeze

# %%
# !pip3 install --upgrade pyTelegramBotAPI
import telebot
from telebot import types
# !pip install python-telegram-bot
# !pip install --upgrade tornado==5.1.1
import telebot
from telebot.types import  ReplyKeyboardMarkup, InlineKeyboardMarkup, InlineKeyboardButton
import pandas as pd
import numpy as np
# !pip install emoji
import emoji
from emoji import emojize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
# ...
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0, but you have tornado 6.1 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached tornado-5.1.1-cp37-cp37m-linux_x86_64.whl
# ...
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
# ...

# %%
bot = telebot.TeleBot('1022369852:AAFgpjNBwQYMc0Jxl2bdyeQjLx3K918jN0A')

page = 1
count = 10


@bot.callback_query_handler(func=lambda call:True)
def callback_query(call):
  global tree
  #Создаем таблицу состояний
  tree = pd.DataFrame(columns={'FirstLevel', 'SecondLevel', 'ThirdLevel', 'FourthLevel', 'Name'}) #Создаем и наполняем таблицу состояний
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#СГУнаСпорте"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Зарядка"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 1, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Зарядка Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 1, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Зарядка Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 1, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Зарядка Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 2, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Суставная Гимнастика"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Суставная Гимнастика Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Суставная Гимнастика Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 2, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Суставная Гимнастика Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 3, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Общая функциональная тренировка"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 3, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Общая функциональная тренировка Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 3, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Общая функциональная тренировка Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 3, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Общая функциональная тренировка Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 4, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Хатха Йога"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 4, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Хатха Йога Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 4, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Хатха Йога Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 4, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Хатха Йога Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 5, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Пилатес"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 5, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Пилатес Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 5, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Пилатес Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 5, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Пилатес Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 6, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Общая силовая тренировка"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 6, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Общая силовая тренировка Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 6, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Общая силовая тренировка Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 1, 'SecondLevel': 6, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Общая силовая тренировка Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#ПроПитание"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Помощник: что сегодня съесть?"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 1, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Произвольный рецепт"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Завтрак"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Завтрак 300 ккал"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 1, 'Name': "Файл: Завтрак 300 ккал рецепт 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 2, 'Name': "Файл: Завтрак 300 ккал рецепт 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Завтрак 1000 ккал"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 1, 'Name': "Файл: Завтрак 1000 ккал рецепт 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 2, 'Name': "Файл: Завтрак 1000 ккал рецепт 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Обед"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Обед 300 ккал"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 3, 'FourthLevel': 1, 'Name': "Файл: Обед 300 ккал рецепт 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 3, 'FourthLevel': 2, 'Name': "Файл: Обед 300 ккал рецепт 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 4, 'FourthLevel': 0, 'Name': "Обед 1000 ккал"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 4, 'FourthLevel': 1, 'Name': "Файл: Обед 1000 ккал рецепт 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 3, 'ThirdLevel': 4, 'FourthLevel': 2, 'Name': "Файл: Обед 1000 ккал рецепт 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Ужин"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 5, 'FourthLevel': 0, 'Name': "Ужин 300 ккал"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 5, 'FourthLevel': 1, 'Name': "Файл: Ужин 300 ккал рецепт 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 5, 'FourthLevel': 2, 'Name': "Файл: Ужин 300 ккал рецепт 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 6, 'FourthLevel': 0, 'Name': "Ужин 1000 ккал"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 6, 'FourthLevel': 1, 'Name': "Файл: Ужин 1000 ккал рецепт 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 2, 'SecondLevel': 4, 'ThirdLevel': 6, 'FourthLevel': 2, 'Name': "Файл: Ужин 1000 ккал рецепт 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#FitЛекции"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Здоровая спина"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 1, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Здоровая спина ссылка"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 2, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Жданов В.А. aka Березовая роща"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Жданов Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Жданов Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 2, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Жданов Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 3, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Приглашенные эксперты"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 3, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Приглашенные эксперты Видео 1"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 3, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "Файл: Приглашенные эксперты Видео 2"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 3, 'SecondLevel': 3, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "Файл: Приглашенные эксперты Видео 3"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#ГТО"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Взрослые"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "18-24 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 1, 'FourthLevel': 1, 'Name': "Файл: Нормы 18-24"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "25-29 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 2, 'FourthLevel': 1, 'Name': "Файл: Нормы 25-29"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "30-34 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 3, 'FourthLevel': 1, 'Name': "Файл: Нормы 30-34"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 4, 'FourthLevel': 0, 'Name': "35-39 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 4, 'FourthLevel': 1, 'Name': "Файл: Нормы 35-39"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 5, 'FourthLevel': 0, 'Name': "40-44 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 5, 'FourthLevel': 1, 'Name': "Файл: Нормы 40-44"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 6, 'FourthLevel': 0, 'Name': "45-49 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 6, 'FourthLevel': 1, 'Name': "Файл: Нормы 45-49"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 7, 'FourthLevel': 0, 'Name': "50-54 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 7, 'FourthLevel': 1, 'Name': "Файл: Нормы 50-54"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 8, 'FourthLevel': 0, 'Name': "55-59 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 8, 'FourthLevel': 1, 'Name': "Файл: Нормы 55-59"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 9, 'FourthLevel': 0, 'Name': "60-69 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 9, 'FourthLevel': 1, 'Name': "Файл: Нормы 60-69"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 10, 'FourthLevel': 0, 'Name': "70 лет и старше"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 1, 'ThirdLevel': 10, 'FourthLevel': 1, 'Name': "Файл: Нормы 70 лет и старше"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Дети"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "6-8 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 1, 'Name': "Файл: Нормы 6-8"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 0, 'Name': "9-10 лет"}, ignore_index=True)   
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 2, 'FourthLevel': 1, 'Name': "Файл: Нормы 9-10"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 3, 'FourthLevel': 0, 'Name': "11-12 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 3, 'FourthLevel': 1, 'Name': "Файл: Нормы 11-12"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 4, 'FourthLevel': 0, 'Name': "13-15 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 4, 'FourthLevel': 1, 'Name': "Файл: Нормы 13-15"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 5, 'FourthLevel': 0, 'Name': "16-17 лет"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 4, 'SecondLevel': 2, 'ThirdLevel': 5, 'FourthLevel': 1, 'Name': "Файл: Нормы 16-17"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 5, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#ДМС"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 5, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Список клиник (общий)"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 5, 'SecondLevel': 1, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Список общий"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 5, 'SecondLevel': 2, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Список клиник (стоматология)"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 5, 'SecondLevel': 2, 'ThirdLevel': 1, 'FourthLevel': 0, 'Name': "Файл: Список стоматологий"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 6, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#Чат для общения"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 6, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Файл: ЗОЖник"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 7, 'SecondLevel': 0, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "#Наши секции"}, ignore_index=True) 
  tree = tree.append({'FirstLevel': 7, 'SecondLevel': 1, 'ThirdLevel': 0, 'FourthLevel': 0, 'Name': "Файл: Ката секций"}, ignore_index=True) 
  tree['FirstLevel'] = tree['FirstLevel'].astype('int')
  tree['SecondLevel'] = tree['SecondLevel'].astype('int')
  tree['ThirdLevel'] = tree['ThirdLevel'].astype('int')
  tree['FourthLevel'] = tree['FourthLevel'].astype('int')
  tree = tree.reindex(columns=['FirstLevel', 'SecondLevel', 'ThirdLevel', 'FourthLevel', 'Name'])
  
  #Определяем функции состояний
  def ChoosingTopics(tree):
    TopicName = np.array([str(tree['Name'][0:1][0]), 0]) #Заполняем первое значение первым именем ветки
    for i in range(1, len(tree)): #Бежим по всей таблице
      if int(tree['FirstLevel'][i-1:i]) != int(tree['FirstLevel'][i:i+1]): #Если текущая строка означает другую ветку, то
        TopicName = np.append(TopicName, tree['Name'][i:i+1]) #Записать имя новой ветки
        TopicName = np.append(TopicName, i) #Записываем ссылку на координаты
    return TopicName 

  def FirstLevel(tree, choos, ChoosingTopicsResult):
    start1 = int(np.argwhere(ChoosingTopicsResult == choos)) #Определяем индекс выбранной кнопки
    start = int(ChoosingTopicsResult[start1+1])+1 #Определяем первую строку отсчета для выбранной ветки
    if start1+2 == len(ChoosingTopicsResult):
      end = len(tree)
    else: end = int(ChoosingTopicsResult[start1 + 3])-1 #Определяем последнюю строку отсчета для выбранной ветки
    FirstName = np.array([np.array(tree['Name'][start:start+1])[0], start]) #Записываем первое имя ветки в этой ветке
    for i in range(start+1, end): 
      if int(tree['SecondLevel'][i-1:i]) != int(tree['SecondLevel'][i:i+1]): #Есди это другая ветка внутри ветки
        FirstName = np.append(FirstName, tree['Name'][i:i+1]) #Дописываем имя новой ветки
        FirstName = np.append(FirstName, i) #Записываем ссылку на координаты
    return FirstName, end

  def SlidingLevel(tree, firstResult, first, endSlinding):
    start1 = int(np.argwhere(firstResult == first)) #Определяем индекс выбранной кнопки
    start = int(firstResult[start1+1])+1 #Определяем первую строку отсчета для выбранной ветки
    if start1+2 == len(firstResult):
      end = endSlinding
    else: end = int(firstResult[start1 + 3])-1 #Определяем последнюю строку отсчета для выбранной ветки
    SlidingLevelName = np.array([np.array(tree['Name'][start:start+1])[0], start]) #Записываем первое имя ветки в этой ветке
    for i in range(start+1, end+1): 
      if int(tree['ThirdLevel'][i-1:i]) != int(tree['ThirdLevel'][i:i+1]): #Есди это другая ветка внутри ветки
        SlidingLevelName = np.append(SlidingLevelName, tree['Name'][i:i+1]) #Дописываем имя новой ветки
        SlidingLevelName = np.append(SlidingLevelName, i) #Записываем ссылку на координаты
    return SlidingLevelName #заглушка

  def SecondLevel(tree, firstResult, first, endSlinding):
    start1 = int(np.argwhere(firstResult == first)) #Определяем индекс выбранной кнопки
    start = int(firstResult[start1+1])+1 #Определяем первую строку отсчета для выбранной ветки
    if start1+2 == len(firstResult):
      end = endSlinding
    else: end = int(firstResult[start1 + 3])-1 #Определяем последнюю строку отсчета для выбранной ветки
    SecondName = np.array([np.array(tree['Name'][start:start+1])[0], start]) #Записываем первое имя ветки в этой ветке
    for i in range(start+1, end+1): 
      if int(tree['ThirdLevel'][i-1:i]) != int(tree['ThirdLevel'][i:i+1]): #Есди это другая ветка внутри ветки
        SecondName = np.append(SecondName, tree['Name'][i:i+1]) #Дописываем имя новой ветки
        SecondName = np.append(SecondName, i) #Записываем ссылку на координаты
    endSecond = end
    return SecondName, endSecond

  def SlidingLevelTupe4(tree, SecondResult, Second, endSecond):
    start1 = int(np.argwhere(SecondResult == Second)) #Определяем индекс выбранной кнопки
    start = int(SecondResult[start1+1])+1 #Определяем первую строку отсчета для выбранной ветки
    if start1+2 == len(SecondResult):
      end = endSecond
    else: end = int(SecondResult[start1 + 3])-1 #Определяем последнюю строку отсчета для выбранной ветки
    slidNameType4 = np.array([np.array(tree['Name'][start:start+1])[0], start]) #Записываем первое имя ветки в этой ветке
    for i in range(start+1, end+1):
        slidNameType4 = np.append(slidNameType4, tree['Name'][i:i+1]) #Дописываем имя новой ветки
        slidNameType4 = np.append(slidNameType4, i) #Записываем ссылку на координаты
    return slidNameType4 #заглушка

  def SlidingLevelTupe5(tree, SecondResult, Second, endSecond):
    start1 = int(np.argwhere(SecondResult == Second)) #Определяем индекс выбранной кнопки
    start = int(SecondResult[start1+1])+1 #Определяем первую строку отсчета для выбранной ветки
    if start1+2 == len(SecondResult):
      end = endSecond
    else: end = int(SecondResult[start1 + 3])-1 #Определяем последнюю строку отсчета для выбранной ветки
    slidNameType4 = np.array([np.array(tree['Name'][start:start+1])[0], start]) #Записываем первое имя ветки в этой ветке
    for i in range(start+1, end+1):
        slidNameType4 = np.append(slidNameType4, tree['Name'][i:i+1]) #Дописываем имя новой ветки
        slidNameType4 = np.append(slidNameType4, i) #Записываем ссылку на координаты
    return slidNameType4 #заглушка

  #Определяем действия бота
  req = call.data.split('_')
  global count
  global page
  global ChoosingTopicsResult
  global firstResult
  global endSlinding
  global slindingResult
  global nextPage
  global nextPage1
  global SecondResult
  global endSecond
  global slindingType5Result
  global s

#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Начало работы----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  if req[0] == 'start':
          ChoosingTopicsResult = ChoosingTopics(tree)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(ChoosingTopicsResult), 2):
            markup.add(InlineKeyboardButton(text=ChoosingTopicsResult[i], callback_data=str(int(i/2))))  
          bot.edit_message_text(emoji.emojize(f"Выберите раздел: :magnifying_glass_tilted_left:"), reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
          page = 0
          count = 0 
#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка чат для общения----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  elif req[0] == '5':
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          # for i in range(0, len(firstResult), 2):
          markup.add(InlineKeyboardButton(text=firstResult[0], url='https://vk.com/'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))
          bot.edit_message_text(emoji.emojize(f"А вот и ссылочка на чат для общения) 	:smiling_face_with_heart-eyes:"), reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)   
#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка секции----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------

  elif req[0] == '6':
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(firstResult), 2):
            markup.add(InlineKeyboardButton(text=firstResult[i], callback_data=str(i/2)))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(emoji.emojize(f"У нас для вас есть целая карта секций, на который вы можете выбрать то, что интересует вас больше всего) :woman_swimming:"), reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)  
#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка - СГУ на спорте----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  elif req[0] == '0':
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(firstResult), 2):
            markup.add(InlineKeyboardButton(text=firstResult[i], callback_data='next-page'+str(i/2)))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(emoji.emojize(f"Выберите тему: 	:flexed_biceps:"), reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)  
          page = 0
          s=0
  elif 'next-page' in req[0]:
      if s==1 :
          page = page + 2
      nextPage = req[0]  
      slindingResult = SlidingLevel(tree, firstResult, firstResult[int(float(req[0][9:]))*2], endSlinding)
      count = len(slindingResult)
      s=0 
      if page < count:  
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[page], callback_data=req[0]))
          markup.add(InlineKeyboardButton(text=emoji.emojize(f':left_arrow: Назад'), callback_data=f'back-page'),InlineKeyboardButton(text=f'{int(page/2)+1}/{int(count/2)}', callback_data=f' '),
                     InlineKeyboardButton(text=emoji.emojize(f'Вперёд :right_arrow:'), callback_data=req[0]))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[0]}"', callback_data='0'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f'Проосмотр видео:', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)
          # if s==0:
          page = page + 2   
  elif req[0] == 'back-page':
      if s==0:
          page = page - 2
      s=1
      if page > 1:
          page = page - 2
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[page], callback_data=nextPage))
          markup.add(InlineKeyboardButton(text=emoji.emojize(f':left_arrow: Назад'), callback_data=f'back-page'),InlineKeyboardButton(text=f'{int(page/2)+1}/{int(count/2)}', callback_data=f' '),
                     InlineKeyboardButton(text=emoji.emojize(f'Вперёд :right_arrow:'), callback_data=nextPage))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[0]}"', callback_data='0'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f'Проосмотр видео:', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)


#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка ДМС----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  elif req[0] == '4':
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(firstResult), 2):
            markup.add(InlineKeyboardButton(text=firstResult[i], callback_data='type3'+str(i/2)))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(emoji.emojize(f"Какое ДМС вас интересует? :man_health_worker:"), reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
          nextPage = 'type3'+str(i/2)
  elif 'type3'in req[0]:
          slindingResult = SlidingLevel(tree, firstResult, firstResult[int(float(nextPage[5:]))*2], endSlinding)
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[0], url='https://vk.com/'))  
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[8]}"', callback_data='4')) 
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))
          bot.edit_message_text(f"Информация по ДМС:", reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)         
#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка ГТО----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  elif req[0] == '3':
          page=0
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(firstResult), 2):
            markup.add(InlineKeyboardButton(text=firstResult[i], callback_data='type4'+str(i/2)))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(emoji.emojize(f"Для какой категории вас интересуют нормы ГТО? :man_cartwheeling:") , reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
  elif 'type4'in req[0]:
          if page == 0:
            SecondResult, endSecond = SecondLevel(tree, firstResult, firstResult[int(float(req[0][5:])*2)], endSlinding)
            nextPage1 = req[0]
          else:   SecondResult, endSecond = SecondLevel(tree, firstResult, firstResult[int(float(nextPage1[5:])*2)], endSlinding)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(SecondResult), 2):
            markup.add(InlineKeyboardButton(text=SecondResult[i], callback_data='typ4'+str(i/2)))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[6]}"', callback_data='3'))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f"Для какой возрастной группы вас интересуют нормы ГТО?", reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
          page+=1
  elif 'typ4'in req[0]:
          slindingResult = SlidingLevel(tree, SecondResult, SecondResult[int(float(req[0][4:]))*2], endSecond)
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[0], callback_data=f' '))  
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{firstResult[int(float(nextPage1[5:]))*2]}"', callback_data='type4')) 
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[6]}"', callback_data='3')) 
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))
          bot.edit_message_text(f"Нормы ГТО:", reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)  
#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка фитлекции----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  elif req[0] == '2':
          page=0
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(firstResult), 2):
            markup.add(InlineKeyboardButton(text=firstResult[i], callback_data='name1'+str(i/2)))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(emoji.emojize(f"Какую лекцию вы хотите послушать? :television:") , reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
          # nextPage = str('name1'+str(i/2))
          s=0
  elif 'name10.0'== req[0]:
          slindingResult = SlidingLevel(tree, firstResult, firstResult[int(float(req[0][5:]))*2], endSlinding)
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[0], url='https://vk.com/'))  
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[4]}"', callback_data='2')) 
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))
          bot.edit_message_text(f'Ссылка на проект "Здоровая спина":', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)      
  elif 'name10.0'!= req[0] and 'name1'in req[0]:
      if s==1 :
          page = page + 2
      nextPage = req[0]  
      slindingResult = SlidingLevel(tree, firstResult, firstResult[int(float(req[0][5:]))*2], endSlinding)
      count = len(slindingResult)
      s=0 
      if page < count:  
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[page], callback_data=req[0]))
          markup.add(InlineKeyboardButton(text=f'<--- Назад', callback_data=f'backpage1'),InlineKeyboardButton(text=f'{int(page/2)+1}/{int(count/2)}', callback_data=f' '),
                     InlineKeyboardButton(text=f'Вперёд --->', callback_data=req[0]))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[4]}"', callback_data='2'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f'Проосмотр видео:', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)
          page = page + 2    
  elif req[0] == 'backpage1':
      if s==0:
          page = page - 2
      s=1
      if page > 1:
          page = page - 2
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingResult[page], callback_data=nextPage))
          markup.add(InlineKeyboardButton(text=emoji.emojize(f':left_arrow: Назад'), callback_data=f'backpage1'),InlineKeyboardButton(text=f'{int(page/2)+1}/{int(count/2)}', callback_data=f' '),
                     InlineKeyboardButton(text=emoji.emojize(f'Вперёд :right_arrow:'), callback_data=nextPage))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[4]}"', callback_data='2'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f'Проосмотр видео:', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)

#------------------------------------------------------------------------------------------------------------------------------------------------------
#--------------------------------------------------------------Ветка пропитание----------------------------------------------------------------------------------------
#------------------------------------------------------------------------------------------------------------------------------------------------------
  elif req[0] == '1':
          page=-1          
          firstResult, endSlinding = FirstLevel(tree, ChoosingTopicsResult[int(req[0])*2], ChoosingTopicsResult)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(firstResult), 2):
            markup.add(InlineKeyboardButton(text=firstResult[i], callback_data='name2'+str(i/2)))
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(emoji.emojize(f"Какой рецеп вы хотите получить? :face_savoring_food:") , reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 

  elif 'name20.0'== req[0]:
          SecondResult, endSecond = SecondLevel(tree, firstResult, firstResult[int(float(req[0][5:]))*2], endSlinding)
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=SecondResult[0], callback_data=f' '))  
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[2]}"', callback_data='1')) 
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))
          bot.edit_message_text(f"Это помощник. Он выдает один произвольный рецепт. Ваш рецепт:", reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
          # nextPage = str('name2'+str(i/2))
  elif 'name20.0'!= req[0] and 'name2'in req[0]:
          if page == -1:
            SecondResult, endSecond = SecondLevel(tree, firstResult, firstResult[int(float(req[0][5:]))*2], endSlinding)
          else:   SecondResult, endSecond = SecondLevel(tree, firstResult, firstResult[int(float(nextPage1[5:])*2)], endSlinding)   
          # SecondResult, endSecond = SecondLevel(tree, firstResult, firstResult[int(float(req[0][5:]))*2], endSlinding)
          markup = InlineKeyboardMarkup()
          for i in range(0, len(SecondResult), 2):
            markup.add(InlineKeyboardButton(text=SecondResult[i], callback_data='type5'+str(i/2)))  
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[2]}"', callback_data='1')) 
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))
          bot.edit_message_text(f"Выберите калорийность:", reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id) 
          nextPage1 = req[0]
          page=0
          s=0
  elif 'type5'in req[0]:
      if s==1 :
          page = page + 2
      nextPage = req[0]   
      slindingType5Result = SlidingLevelTupe5(tree, SecondResult, SecondResult[int(float(req[0][5:]))*2], endSecond)
      count = len(slindingType5Result)
      s=0 
      if page < count:  
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingType5Result[page], callback_data=req[0]))
          markup.add(InlineKeyboardButton(text=emoji.emojize(f':left_arrow: Назад'), callback_data=f'backpage2'),InlineKeyboardButton(text=f'{int(page/2)+1}/{int(count/2)}', callback_data=f' '),
                     InlineKeyboardButton(text=emoji.emojize(f'Вперёд :right_arrow:'), callback_data=req[0]))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "Калорийность"', callback_data=nextPage1))  
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[2]}"', callback_data='1'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f'Рецепты: ', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)
          page = page + 2    
  elif req[0] == 'backpage2':
      if s==0:
          page = page - 2
      s=1
      if page > 1:
          page = page - 2
          markup = InlineKeyboardMarkup()
          markup.add(InlineKeyboardButton(text=slindingType5Result[page], callback_data=f' '))
          markup.add(InlineKeyboardButton(text=emoji.emojize(f':left_arrow: Назад'), callback_data=f'backpage2'),InlineKeyboardButton(text=f'{int(page/2)+1}/{int(count/2)}', callback_data=f' '),
                     InlineKeyboardButton(text=emoji.emojize(f'Вперёд :right_arrow:'), callback_data=nextPage))
          markup.add(InlineKeyboardButton(text=f'Вернуться к "Калорийность"', callback_data=nextPage1))           
          markup.add(InlineKeyboardButton(text=f'Вернуться к "{ChoosingTopicsResult[2]}"', callback_data='1'))  
          markup.add(InlineKeyboardButton(text='Вернуться на главную', callback_data='start'))  
          bot.edit_message_text(f'Рецепты:', reply_markup = markup, chat_id=call.message.chat.id, message_id=call.message.message_id)






#Обработчик входящих сообщений
@bot.message_handler(commands=['start'])
def start(m):
    global count
    global page
    markup = InlineKeyboardMarkup()
    markup.add(InlineKeyboardButton(text=f'Начнем', callback_data=f'start'))
    bot.send_message(m.from_user.id, emoji.emojize("Добрый день!:hand_with_fingers_splayed: Вы хотите узнать что-то про ЗОЖ?:red_question_mark: Тогда, нажмите кнопку: :play_button:"), reply_markup = markup)

@bot.message_handler()
def start(m):
    bot.send_message(m.from_user.id, emoji.emojize("Увы! :weary_face: Я умею общаться только кнопками(	:woman_facepalming: Поэтому, пожалуйста, напишите мне /start, чтобы снова начать общение! :beating_heart:"))


if __name__ == '__main__':
    bot.polling(none_stop=True)
# Out:
# 2022-10-27 03:41:01,294 (__init__.py:1087 MainThread) ERROR - TeleBot: "Threaded polling exception: A request to the Telegram API was unsuccessful. Error code: 400. Description: Bad Request: message is not modified: specified new message content and reply markup are exactly the same as a current content and reply markup of the message"
# ERROR:TeleBot:Threaded polling exception: A request to the Telegram API was unsuccessful. Error code: 400. Description: Bad Request: message is not modified: specified new message content and reply markup are exactly the same as a current content and reply markup of the message
# 2022-10-27 03:41:01,307 (__init__.py:1089 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/telebot/__init__.py", line 1078, in __threaded_polling
#     self.worker_pool.raise_exceptions()
#   File "/usr/local/lib/python3.7/dist-packages/telebot/util.py", line 154, in raise_exceptions
# ...

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 216 kB 9.5 MB/s
# ...
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=af34f3466ae6ada2d1166f5156bd3916e44a026148429e456662ede135d8c7ab
#   Stored in directory: /root/.cache/pip/wheels/77/75/99/51c2a119f4cfd3af7b49cc57e4f737bed7e40b348a85d82804
# Successfully built emoji
# ...
